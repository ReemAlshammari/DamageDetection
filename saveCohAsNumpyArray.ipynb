# %%
import numpy as np
from osgeo import gdal

filepath01 = r"/merged/interferograms/20150428_20150802/filt_fine.cor"
filepath02 = r"/merged/interferograms/20150802_20160210/filt_fine.cor"
filepath03 = r"/merged/interferograms/20160210_20160820/filt_fine.cor"
filepath04 = r"/merged/interferograms/20160820_20160913/filt_fine.cor"
filepath05 = r"/merged/interferograms/20160913_20161001/filt_fine.cor"
filepath06 = r"/merged/interferograms/20161001_20161025/filt_fine.cor"
filepath07 = r"/merged/interferograms/20161025_20161106/filt_fine.cor"
filepath08 = r"/merged/interferograms/20161106_20161118/filt_fine.cor"
filepath09 = r"/merged/interferograms/20161118_20161130/filt_fine.cor"
filepath10 = r"/merged/interferograms/20161130_20161212/filt_fine.cor"
filepath11 = r"/merged/interferograms/20161212_20161224/filt_fine.cor"

filepath12 = r"/merged/interferograms/20161224_20170105/filt_fine.cor"
filepath13 = r"/merged/interferograms/20170105_20170117/filt_fine.cor"
filepath14 = r"/merged/interferograms/20170117_20170129/filt_fine.cor"
filepath15 = r"/merged/interferograms/20170129_20170210/filt_fine.cor"
filepath16 = r"/merged/interferograms/20170210_20170222/filt_fine.cor"
filepath17 = r"/merged/interferograms/20170222_20170306/filt_fine.cor"
filepath18 = r"/merged/interferograms/20170306_20170318/filt_fine.cor"
filepath19 = r"/merged/interferograms/20170318_20170330/filt_fine.cor"
filepath20 = r"/merged/interferograms/20170330_20170411/filt_fine.cor"
filepath21 = r"/merged/interferograms/20170411_20170423/filt_fine.cor"
filepath22 = r"/merged/interferograms/20170423_20170505/filt_fine.cor"

filepath23 = r"/merged/interferograms/20170505_20170517/filt_fine.cor"
filepath24 = r"/merged/interferograms/20170117_20170129/filt_fine.cor"
filepath25 = r"/merged/interferograms/20170529_20170610/filt_fine.cor"
filepath26 = r"/merged/interferograms/20170610_20170622/filt_fine.cor"
filepath27 = r"/merged/interferograms/20170622_20170704/filt_fine.cor"
filepath28 = r"/merged/interferograms/20170704_20170716/filt_fine.cor"
filepath29 = r"/merged/interferograms/20170716_20170728/filt_fine.cor"
filepath30 = r"/merged/interferograms/20170728_20170809/filt_fine.cor"
filepath31 = r"/merged/interferograms/20170809_20170821/filt_fine.cor"
filepath32 = r"/merged/interferograms/20170821_20170902/filt_fine.cor"

filepath33 = r"/merged/interferograms/20170902_20170914/filt_fine.cor"
filepath34 = r"/merged/interferograms/20170914_20170926/filt_fine.cor"
filepath35 = r"/merged/interferograms/20170926_20171008/filt_fine.cor"
filepath36 = r"/merged/interferograms/20171008_20171101/filt_fine.cor"
filepath37 = r"/merged/interferograms/20171101_20171113/filt_fine.cor"
filepath38 = r"/merged/interferograms/20171113_20171125/filt_fine.cor"
filepath39 = r"/merged/interferograms/20171125_20171207/filt_fine.cor"
filepath40 = r"/merged/interferograms/20171207_20171219/filt_fine.cor"
filepath41 = r"/merged/interferograms/20171219_20171231/filt_fine.cor"

filepath42 = r"/merged/interferograms/20171231_20180112/filt_fine.cor"
filepath43 = r"/merged/interferograms/20180112_20180124/filt_fine.cor"
filepath44 = r"/merged/interferograms/20180124_20180205/filt_fine.cor"
filepath45 = r"/merged/interferograms/20180205_20180217/filt_fine.cor"
filepath46 = r"/merged/interferograms/20180217_20180301/filt_fine.cor"
filepath47 = r"/merged/interferograms/20180301_20180313/filt_fine.cor"
filepath48 = r"/merged/interferograms/20180313_20180325/filt_fine.cor"
filepath49 = r"/merged/interferograms/20180325_20180406/filt_fine.cor"
filepath50 = r"/merged/interferograms/20180406_20180418/filt_fine.cor"
filepath51 = r"/merged/interferograms/20180418_20180430/filt_fine.cor"

filepath52 = r"/merged/interferograms/20180430_20180512/filt_fine.cor"
filepath53 = r"/merged/interferograms/20180512_20180524/filt_fine.cor"
filepath54 = r"/merged/interferograms/20180524_20180605/filt_fine.cor"
filepath55 = r"/merged/interferograms/20180605_20180617/filt_fine.cor"
filepath56 = r"/merged/interferograms/20180617_20180629/filt_fine.cor"
filepath57 = r"/merged/interferograms/20180629_20180711/filt_fine.cor"
filepath58 = r"/merged/interferograms/20180711_20180723/filt_fine.cor"
filepath59 = r"/merged/interferograms/20180723_20180804/filt_fine.cor"
filepath60 = r"/merged/interferograms/20180804_20180816/filt_fine.cor"
filepath61 = r"/merged/interferograms/20180816_20180909/filt_fine.cor"

filepath62 = r"/merged/interferograms/20180909_20180921/filt_fine.cor"
filepath63 = r"/merged/interferograms/20180921_20181003/filt_fine.cor"
filepath64 = r"/merged/interferograms/20181003_20181027/filt_fine.cor"
filepath65 = r"/merged/interferograms/20181027_20181108/filt_fine.cor"
filepath66 = r"/merged/interferograms/20181108_20181120/filt_fine.cor"
filepath67 = r"/merged/interferograms/20181120_20181202/filt_fine.cor"


# Open the file:
ds01 = np.array(gdal.Open(filepath01).ReadAsArray())
ds02 = np.array(gdal.Open(filepath02).ReadAsArray())
ds03 = np.array(gdal.Open(filepath03).ReadAsArray())
ds04 = np.array(gdal.Open(filepath04).ReadAsArray())
ds05 = np.array(gdal.Open(filepath05).ReadAsArray())
ds06 = np.array(gdal.Open(filepath06).ReadAsArray())
ds07 = np.array(gdal.Open(filepath07).ReadAsArray())
ds08 = np.array(gdal.Open(filepath08).ReadAsArray())
ds09 = np.array(gdal.Open(filepath09).ReadAsArray())
ds10 = np.array(gdal.Open(filepath10).ReadAsArray())

ds11 = np.array(gdal.Open(filepath11).ReadAsArray())
ds12 = np.array(gdal.Open(filepath12).ReadAsArray())
ds13 = np.array(gdal.Open(filepath13).ReadAsArray())
ds14 = np.array(gdal.Open(filepath14).ReadAsArray())
ds15 = np.array(gdal.Open(filepath15).ReadAsArray())
ds16 = np.array(gdal.Open(filepath16).ReadAsArray())
ds17 = np.array(gdal.Open(filepath17).ReadAsArray())
ds18 = np.array(gdal.Open(filepath18).ReadAsArray())
ds19 = np.array(gdal.Open(filepath19).ReadAsArray())
ds20 = np.array(gdal.Open(filepath20).ReadAsArray())

ds21 = np.array(gdal.Open(filepath21).ReadAsArray())
ds22 = np.array(gdal.Open(filepath22).ReadAsArray())
ds23 = np.array(gdal.Open(filepath23).ReadAsArray())
ds24 = np.array(gdal.Open(filepath24).ReadAsArray())
ds25 = np.array(gdal.Open(filepath25).ReadAsArray())
ds26 = np.array(gdal.Open(filepath26).ReadAsArray())
ds27 = np.array(gdal.Open(filepath27).ReadAsArray())
ds28 = np.array(gdal.Open(filepath28).ReadAsArray())
ds29 = np.array(gdal.Open(filepath29).ReadAsArray())
ds30 = np.array(gdal.Open(filepath30).ReadAsArray())

ds31 = np.array(gdal.Open(filepath31).ReadAsArray())
ds32 = np.array(gdal.Open(filepath32).ReadAsArray())
ds33 = np.array(gdal.Open(filepath33).ReadAsArray())
ds34 = np.array(gdal.Open(filepath34).ReadAsArray())
ds35 = np.array(gdal.Open(filepath35).ReadAsArray())
ds36 = np.array(gdal.Open(filepath36).ReadAsArray())
ds37 = np.array(gdal.Open(filepath37).ReadAsArray())
ds38 = np.array(gdal.Open(filepath38).ReadAsArray())
ds39 = np.array(gdal.Open(filepath39).ReadAsArray())
ds40 = np.array(gdal.Open(filepath40).ReadAsArray())

ds41 = np.array(gdal.Open(filepath41).ReadAsArray())
ds42 = np.array(gdal.Open(filepath42).ReadAsArray())
ds43 = np.array(gdal.Open(filepath43).ReadAsArray())
ds44 = np.array(gdal.Open(filepath44).ReadAsArray())
ds45 = np.array(gdal.Open(filepath45).ReadAsArray())
ds46 = np.array(gdal.Open(filepath46).ReadAsArray())
ds47 = np.array(gdal.Open(filepath47).ReadAsArray())
ds48 = np.array(gdal.Open(filepath48).ReadAsArray())
ds49 = np.array(gdal.Open(filepath49).ReadAsArray())
ds50 = np.array(gdal.Open(filepath50).ReadAsArray())

ds51 = np.array(gdal.Open(filepath51).ReadAsArray())
ds52 = np.array(gdal.Open(filepath52).ReadAsArray())
ds53 = np.array(gdal.Open(filepath53).ReadAsArray())
ds54 = np.array(gdal.Open(filepath54).ReadAsArray())
ds55 = np.array(gdal.Open(filepath55).ReadAsArray())
ds56 = np.array(gdal.Open(filepath56).ReadAsArray())
ds57 = np.array(gdal.Open(filepath57).ReadAsArray())
ds58 = np.array(gdal.Open(filepath58).ReadAsArray())
ds59 = np.array(gdal.Open(filepath59).ReadAsArray())
ds60 = np.array(gdal.Open(filepath60).ReadAsArray())

ds61 = np.array(gdal.Open(filepath61).ReadAsArray())
ds62 = np.array(gdal.Open(filepath62).ReadAsArray())
ds63 = np.array(gdal.Open(filepath63).ReadAsArray())
ds64 = np.array(gdal.Open(filepath64).ReadAsArray())
ds65 = np.array(gdal.Open(filepath65).ReadAsArray())
ds66 = np.array(gdal.Open(filepath66).ReadAsArray())
ds67 = np.array(gdal.Open(filepath67).ReadAsArray())

array_tuple1 = np.stack((ds01,ds02,ds03,ds04,ds05,ds06,ds07,ds08,ds09,ds10,
               ds11,ds12, ds13,ds14,ds15,ds16,ds17,ds18,ds19,ds20,
               ds21,ds22,ds23,ds24,ds25,ds26,ds27,ds28,ds29,ds30,
               ds31,ds32,ds33,ds34,ds35,ds36,ds37,ds38,ds39,ds40,
               ds41,ds42,ds43,ds44,ds45,ds46,ds47,ds48,ds49,ds50,
               ds51,ds52,ds53,ds54,ds55,ds56,ds57,ds58,ds59,ds60,
              ds61,ds62,ds63,ds64,ds65,ds66,ds67), axis=-1)

np.save('data_test__largeArea.npy', array_tuple1)
print(array_tuple1.shape)
